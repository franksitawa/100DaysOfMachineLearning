# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format
# Out:
# 2023-07-19 10:35:00.171081: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-19 10:35:00.210747: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-19 10:35:00.449508: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-19 10:35:00.451027: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 10:35:01.355562: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
train_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")
test_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_test.csv")

# %%
scale_factor=1000.0

# Scale the training set's label.
train_df["median_house_value"] /= scale_factor
# Scale the test set's label
test_df["median_house_value"] /= scale_factor

# %%
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.experimental.RMSprop(learning_rate=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model               


def train_model(model, df, feature, label, my_epochs, 
                my_batch_size=None, my_validation_split=0.1):
  """Feed a dataset into the model in order to train it."""

  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=my_batch_size,
                      epochs=my_epochs,
                      validation_split=my_validation_split)

  # Gather the model's trained weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
  epochs = history.epoch
  
  # Isolate the root mean squared error for each epoch.
  hist = pd.DataFrame(history.history)
  rmse = hist["root_mean_squared_error"]

  return epochs, rmse, history.history   

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
def plot_the_loss_curve(epochs, mae_training, mae_validation):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs[1:], mae_training[1:], label="Training Loss")
  plt.plot(epochs[1:], mae_validation[1:], label="Validation Loss")
  plt.legend()
  
  # We're not going to plot the first epoch, since the loss on the first epoch
  # is often substantially greater than the loss for other epochs.
  merged_mae_lists = mae_training[1:] + mae_validation[1:]
  highest_loss = max(merged_mae_lists)
  lowest_loss = min(merged_mae_lists)
  delta = highest_loss - lowest_loss
  print(delta)

  top_of_y_axis = highest_loss + (delta * 0.05)
  bottom_of_y_axis = lowest_loss - (delta * 0.05)
   
  plt.ylim([bottom_of_y_axis, top_of_y_axis])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.08
epochs = 30
batch_size = 100

# Split the original training set into a reduced training set and a
# validation set. 
validation_split = 0.2

# Identify the feature and the label.
my_feature = "median_income"    # the median income on a specific city block.
my_label = "median_house_value" # the median house value on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Invoke the functions to build and train the model.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# Epoch 1/30
# 136/136 [==============================] - 0s 1ms/step - loss: 39467.9102 - root_mean_squared_error: 198.6653 - val_loss: 47870.3203 - val_root_mean_squared_error: 218.7929
# Epoch 2/30
# 136/136 [==============================] - 0s 700us/step - loss: 22743.2520 - root_mean_squared_error: 150.8087 - val_loss: 27935.1758 - val_root_mean_squared_error: 167.1382
# Epoch 3/30
# 136/136 [==============================] - 0s 690us/step - loss: 12013.2090 - root_mean_squared_error: 109.6048 - val_loss: 15132.2412 - val_root_mean_squared_error: 123.0132
# Epoch 4/30
# 136/136 [==============================] - 0s 706us/step - loss: 7203.6094 - root_mean_squared_error: 84.8741 - val_loss: 9532.8643 - val_root_mean_squared_error: 97.6364
# Epoch 5/30
# 136/136 [==============================] - 0s 755us/step - loss: 6514.0112 - root_mean_squared_error: 80.7094 - val_loss: 9247.4834 - val_root_mean_squared_error: 96.1638
# Epoch 6/30
# 136/136 [==============================] - 0s 734us/step - loss: 6514.2568 - root_mean_squared_error: 80.7109 - val_loss: 9282.0713 - val_root_mean_squared_error: 96.3435
# Epoch 7/30
# 136/136 [==============================] - 0s 729us/step - loss: 6513.7695 - root_mean_squared_error: 80.7079 - val_loss: 9328.6719 - val_root_mean_squared_error: 96.5851
# Epoch 8/30
# 136/136 [==============================] - 0s 690us/step - loss: 6513.5137 - root_mean_squared_error: 80.7063 - val_loss: 9383.6475 - val_root_mean_squared_error: 96.8692
# Epoch 9/30
# 136/136 [==============================] - 0s 723us/step - loss: 6514.2534 - root_mean_squared_error: 80.7109 - val_loss: 9247.0664 - val_root_mean_squared_error: 96.1617
# Epoch 10/30
# 136/136 [==============================] - 0s 736us/step - loss: 6513.5464 - root_mean_squared_error: 80.7065 - val_loss: 9252.5195 - val_root_mean_squared_error: 96.1900
# Epoch 11/30
# 136/136 [==============================] - 0s 873us/step - loss: 6512.8628 - root_mean_squared_error: 80.7023 - val_loss: 9148.6602 - val_root_mean_squared_error: 95.6486
# Epoch 12/30
# 136/136 [==============================] - 0s 979us/step - loss: 6514.2236 - root_mean_squared_error: 80.7107 - val_loss: 9255.7236 - val_root_mean_squared_error: 96.2067
# Epoch 13/30
# 136/136 [==============================] - 0s 703us/step - loss: 6514.2583 - root_mean_squared_error: 80.7110 - val_loss: 9254.2998 - val_root_mean_squared_error: 96.1993
# Epoch 14/30
# 136/136 [==============================] - 0s 704us/step - loss: 6513.5884 - root_mean_squared_error: 80.7068 - val_loss: 9217.2031 - val_root_mean_squared_error: 96.0063
# Epoch 15/30
# 136/136 [==============================] - 0s 738us/step - loss: 6514.0967 - root_mean_squared_error: 80.7100 - val_loss: 9261.8018 - val_root_mean_squared_error: 96.2383
# Epoch 16/30
# 136/136 [==============================] - 0s 745us/step - loss: 6511.4053 - root_mean_squared_error: 80.6933 - val_loss: 9156.1113 - val_root_mean_squared_error: 95.6876
# Epoch 17/30
# 136/136 [==============================] - 0s 680us/step - loss: 6513.8906 - root_mean_squared_error: 80.7087 - val_loss: 9276.7324 - val_root_mean_squared_error: 96.3158
# Epoch 18/30
# 136/136 [==============================] - 0s 682us/step - loss: 6512.2363 - root_mean_squared_error: 80.6984 - val_loss: 9459.0596 - val_root_mean_squared_error: 97.2577
# Epoch 19/30
# 136/136 [==============================] - 0s 663us/step - loss: 6513.5967 - root_mean_squared_error: 80.7069 - val_loss: 9185.4834 - val_root_mean_squared_error: 95.8409
# Epoch 20/30
# 136/136 [==============================] - 0s 689us/step - loss: 6513.4087 - root_mean_squared_error: 80.7057 - val_loss: 9188.0762 - val_root_mean_squared_error: 95.8545
# Epoch 21/30
# 136/136 [==============================] - 0s 675us/step - loss: 6514.6304 - root_mean_squared_error: 80.7133 - val_loss: 9258.9951 - val_root_mean_squared_error: 96.2237
# Epoch 22/30
# 136/136 [==============================] - 0s 680us/step - loss: 6511.4102 - root_mean_squared_error: 80.6933 - val_loss: 9410.2021 - val_root_mean_squared_error: 97.0062
# Epoch 23/30
# 136/136 [==============================] - 0s 686us/step - loss: 6511.7588 - root_mean_squared_error: 80.6955 - val_loss: 9206.1016 - val_root_mean_squared_error: 95.9484
# Epoch 24/30
# 136/136 [==============================] - 0s 688us/step - loss: 6512.6372 - root_mean_squared_error: 80.7009 - val_loss: 9224.5410 - val_root_mean_squared_error: 96.0445
# Epoch 25/30
# 136/136 [==============================] - 0s 793us/step - loss: 6513.6323 - root_mean_squared_error: 80.7071 - val_loss: 9167.7471 - val_root_mean_squared_error: 95.7483
# Epoch 26/30
# 136/136 [==============================] - 0s 679us/step - loss: 6514.3325 - root_mean_squared_error: 80.7114 - val_loss: 9221.3857 - val_root_mean_squared_error: 96.0280
# Epoch 27/30
# 136/136 [==============================] - 0s 714us/step - loss: 6513.0210 - root_mean_squared_error: 80.7033 - val_loss: 9209.1133 - val_root_mean_squared_error: 95.9641
# Epoch 28/30
# 136/136 [==============================] - 0s 677us/step - loss: 6513.4204 - root_mean_squared_error: 80.7058 - val_loss: 9327.8809 - val_root_mean_squared_error: 96.5810
# Epoch 29/30
# 136/136 [==============================] - 0s 821us/step - loss: 6512.1655 - root_mean_squared_error: 80.6980 - val_loss: 9248.0244 - val_root_mean_squared_error: 96.1666
# Epoch 30/30
# 136/136 [==============================] - 0s 711us/step - loss: 6514.0420 - root_mean_squared_error: 80.7096 - val_loss: 9303.6787 - val_root_mean_squared_error: 96.4556
# 86.4449234008789

# %%
train_df.head(n=1000)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -114.3      34.2                15.0       5612.0          1283.0
# 1       -114.5      34.4                19.0       7650.0          1901.0
# 2       -114.6      33.7                17.0        720.0           174.0
# 3       -114.6      33.6                14.0       1501.0           337.0
# 4       -114.6      33.6                20.0       1454.0           326.0
# ..         ...       ...                 ...          ...             ...
# 995     -117.1      32.5                 8.0       6533.0          1217.0
# 996     -117.1      34.6                 6.0       5110.0          1044.0
# 997     -117.1      34.2                22.0       4397.0           931.0
# 998     -117.1      34.0                24.0       4144.0           826.0
# 999     -117.1      33.6                 6.0       1868.0           289.0
#
#      population  households  median_income  median_house_value
# 0        1015.0       472.0            1.5                66.9
# 1        1129.0       463.0            1.8                80.1
# 2         333.0       117.0            1.7                85.7
# 3         515.0       226.0            3.2                73.4
# 4         624.0       262.0            1.9                65.5
# ..          ...         ...            ...                 ...
# 995      4797.0      1177.0            4.0               144.4
# 996      1938.0       724.0            3.2               112.8
# 997      1145.0       445.0            4.5               108.4
# 998      2127.0       772.0            2.5                96.0
# 999       750.0       247.0            4.4               307.6
#
# [1000 rows x 9 columns]

# %%
# The following variables are the hyperparameters.
learning_rate = 0.08
epochs = 70
batch_size = 100

# Split the original training set into a reduced training set and a
# validation set. 
validation_split = 0.2

# Identify the feature and the label.
my_feature = "median_income"    # the median income on a specific city block.
my_label = "median_house_value" # the median house value on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Invoke the functions to build and train the model.
my_model = build_model(learning_rate)
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index))
epochs, rmse, history = train_model(my_model, shuffled_train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
# Epoch 55/70
# 136/136 [==============================] - 0s 709us/step - loss: 7097.7998 - root_mean_squared_error: 84.2484 - val_loss: 6686.7241 - val_root_mean_squared_error: 81.7724
# Epoch 56/70
# 136/136 [==============================] - 0s 961us/step - loss: 7097.5005 - root_mean_squared_error: 84.2467 - val_loss: 6684.8037 - val_root_mean_squared_error: 81.7607
# Epoch 57/70
# 136/136 [==============================] - 0s 757us/step - loss: 7098.1260 - root_mean_squared_error: 84.2504 - val_loss: 6699.8516 - val_root_mean_squared_error: 81.8526
# Epoch 58/70
# 136/136 [==============================] - 0s 709us/step - loss: 7098.8955 - root_mean_squared_error: 84.2549 - val_loss: 6689.4111 - val_root_mean_squared_error: 81.7888
# Epoch 59/70
# 136/136 [==============================] - 0s 695us/step - loss: 7098.1714 - root_mean_squared_error: 84.2506 - val_loss: 6679.4121 - val_root_mean_squared_error: 81.7277
# Epoch 60/70
# 136/136 [==============================] - 0s 794us/step - loss: 7098.1558 - root_mean_squared_error: 84.2506 - val_loss: 6686.3076 - val_root_mean_squared_error: 81.7698
# Epoch 61/70
# 136/136 [==============================] - 0s 729us/step - loss: 7097.8594 - root_mean_squared_error: 84.2488 - val_loss: 6688.7417 - val_root_mean_squared_error: 81.7847
# Epoch 62/70
# 136/136 [==============================] - 0s 690us/step - loss: 7097.2368 - root_mean_squared_error: 84.2451 - val_loss: 6696.2339 - val_root_mean_squared_error: 81.8305
# Epoch 63/70
# 136/136 [==============================] - 0s 814us/step - loss: 7097.8301 - root_mean_squared_error: 84.2486 - val_loss: 6684.6670 - val_root_mean_squared_error: 81.7598
# Epoch 64/70
# 136/136 [==============================] - 0s 851us/step - loss: 7096.5601 - root_mean_squared_error: 84.2411 - val_loss: 6700.0190 - val_root_mean_squared_error: 81.8536
# Epoch 65/70
# 136/136 [==============================] - 0s 730us/step - loss: 7096.1860 - root_mean_squared_error: 84.2389 - val_loss: 6691.1465 - val_root_mean_squared_error: 81.7994
# Epoch 66/70
# 136/136 [==============================] - 0s 725us/step - loss: 7097.0625 - root_mean_squared_error: 84.2441 - val_loss: 6693.2847 - val_root_mean_squared_error: 81.8125
# Epoch 67/70
# 136/136 [==============================] - 0s 811us/step - loss: 7098.3237 - root_mean_squared_error: 84.2515 - val_loss: 6684.2876 - val_root_mean_squared_error: 81.7575
# Epoch 68/70
# 136/136 [==============================] - 0s 705us/step - loss: 7096.4980 - root_mean_squared_error: 84.2407 - val_loss: 6677.6382 - val_root_mean_squared_error: 81.7168
# Epoch 69/70
# 136/136 [==============================] - 0s 773us/step - loss: 7098.0630 - root_mean_squared_error: 84.2500 - val_loss: 6678.5610 - val_root_mean_squared_error: 81.7225
# Epoch 70/70
# 136/136 [==============================] - 0s 850us/step - loss: 7097.8545 - root_mean_squared_error: 84.2488 - val_loss: 6687.5220 - val_root_mean_squared_error: 81.7773
# 79.20002746582031

# %%
x_test = test_df[my_feature]
y_test = test_df[my_label]

results = my_model.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 30/30 [==============================] - 0s 490us/step - loss: 7009.3140 - root_mean_squared_error: 83.7216
